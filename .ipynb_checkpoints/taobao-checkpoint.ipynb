# %%
import urllib
from selenium import webdriver
import os
import requests
import hashlib
import io
from PIL import Image
from selenium.webdriver.support.ui import WebDriverWait

# %%
import pandas as pd 
brandname="brand abc"
itemname="item bbb"
def search_and_download():
    target_folder=os.path.join(brandname,itemname)
    if not os.path.exists(brandname):
        os.makedirs(brandname)    
    if not os.path.exists(target_folder):
        os.makedirs(target_folder)
    
    for elem in src:
        persist_image(target_folder,elem)

def persist_image(folder_path:str,url:str):
    try:
        image_content = requests.get(url).content

    except Exception as e:
        print(f"ERROR - Could not download {url} - {e}")
        print(1)

    try:
        image_file = io.BytesIO(image_content)
        image = Image.open(image_file).convert('RGB')
        file_path = os.path.join(folder_path,hashlib.sha1(image_content).hexdigest()[:10] + '.jpg')
        with open(file_path, 'wb') as f:
            image.save(f, "JPEG", quality=85)
        print(f"SUCCESS - saved {url} - as {file_path}")
    except Exception as e:
        print(2)
        print(f"ERROR - Could not save {url} - {e}")

# %%
data = pd.read_csv("input.csv")
data.head()
for i in range(len(data['url'])):
    print(data['url'][i])
    print(data['brand'][i])
# Out:
# https://item.taobao.com/item.htm?spm=a312a.7700824.w4004-22612662286.2.5f519e831e9NGj&id=608274915235
# minky
# https://item.taobao.com/item.htm?spm=a312a.7700824.w4004-22612662286.4.5f519e831e9NGj&id=611988650152
# minky
# https://item.taobao.com/item.htm?spm=a312a.7700824.w4004-22612662286.6.5f519e831e9NGj&id=624361503104
# minky
# https://item.taobao.com/item.htm?spm=a312a.7700824.w4004-22612662286.8.5f519e831e9NGj&id=617341972356
# minky

# %%
itemname=driver.find_elements_by_class_name('tb-main-title')[0].get_attribute('innerHTML')
print(itemname)
# Out:
#             「初恋」赵露思同款耳钉花朵耳环耳夹仙气森系超仙女无耳洞蚊香盘

# %%
driver = webdriver.Chrome()
#driver.get('home/denjo/Downloads/sns_automation/chromedriver')
#driver.get('https://item.taobao.com/item.htm?id=589892452897') 
for i in range(len(data['url'])):
    print(data['url'][i])
    brandname=(data['brand'][i])
    driver.get(data['url'][i])
  #  driver.get('https://item.taobao.com/item.htm?spm=a312a.7700824.w4004-22612662286.2.5f519e83O0WkbL&id=608274915235')

    wait = WebDriverWait(driver, 10)

    try:
        driver.find_elements_by_xpath('//*[@id="sufei-dialog-close"]')[0].click()
    except:
        print("no login dialogue1 IMPORTANTTT _____________")
    try:
        driver.find_elements_by_xpath('//*[@id="sufei-dialog-close"]')[0].click()
    except:
        print("no login dialogue2 IMPORTANTTT _____________")
    itemname=driver.find_elements_by_class_name('tb-main-title')[0].get_attribute('innerHTML')

    try:
        driver.find_elements_by_xpath('//*[@id="J_UlThumb"]/li[2]/div')[0].click()
    except:
        print('gg IMPORTANTTT _____________')
    src=list()

    for x in range(15):
        try:
            driver.find_elements_by_xpath('//*[@id="J_TbViewerThumb-'+str(x)+'"]')[0].click()
        except:
            print('gg2')
        print(x)
        try:
            src.append(driver.find_elements_by_xpath('//*[@id="tb-viewer-panel-'+str(x)+'"]/a')[0].get_attribute("href"))
        except:
            print('fail')

    #get link video
    #vidsrc=driver.find_elements_by_xpath('/html/head/link[12]')[0].get_attribute('href')
    vidsrc=driver.find_element_by_css_selector("*[rel='alternate']").get_attribute('href')
    print(vidsrc)
    driver.get(vidsrc)
    x=1
    while(x==1):
        try:
            driver.find_elements_by_xpath('/html/body/div[3]/div[1]/div[1]/div[1]/div[1]/img')[0].click()
            vidlnk=driver.find_elements_by_xpath('//*[@id="videoTag"]')[0].get_attribute('src') 
            print(vidlnk)
            x=0
        except:
            element = WebDriverWait(driver, 10)
            print("uh oh")
    #download image
    search_and_download()
    #download vid
    target_folder=os.path.join(brandname,itemname)
    urllib.request.urlretrieve(vidlnk, os.path.join(target_folder,'videoname.mp4'))
# Out:
# https://item.taobao.com/item.htm?spm=a312a.7700824.w4004-22612662286.2.5f519e831e9NGj&id=608274915235
# no login dialogue2 IMPORTANTTT _____________
# 0
# 1
# 2
# 3
# 4
# gg2
# 5
# fail
# gg2
# 6
# fail
# gg2
# 7
# fail
# gg2
# 8
# fail
# gg2
# 9
# fail
# gg2
# 10
# fail
# gg2
# 11
# fail
# gg2
# 12
# fail
# gg2
# 13
# fail
# gg2
# 14
# fail
# https://world.taobao.com/item/608274915235.htm
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# uh oh
# https://cloud.video.taobao.com/play/u/2240926302/p/2/e/6/t/1/248982637689.mp4?appKey=38829
# SUCCESS - saved https://gd3.alicdn.com/imgextra/i4/2240926302/O1CN01FsCJzM1wQMaQe4Bwa_!!2240926302.jpg - as minky/
#             「初恋」赵露思同款耳钉花朵耳环耳夹仙气森系超仙女无耳洞蚊香盘
#         /2a6a7f33f0.jpg
# SUCCESS - saved https://gd1.alicdn.com/imgextra/i1/2240926302/O1CN01y4MEbV1wQMaQ5rx0W_!!2240926302.jpg - as minky/
#             「初恋」赵露思同款耳钉花朵耳环耳夹仙气森系超仙女无耳洞蚊香盘
#         /e0ddc3aaa4.jpg
# SUCCESS - saved https://gd3.alicdn.com/imgextra/i3/2240926302/O1CN014IoipL1wQMa0Ae6bh_!!2240926302.jpg - as minky/
#             「初恋」赵露思同款耳钉花朵耳环耳夹仙气森系超仙女无耳洞蚊香盘
#         /bd1d4896d7.jpg
# SUCCESS - saved https://gd2.alicdn.com/imgextra/i2/2240926302/O1CN01d5g1ta1wQMc6aqcFd_!!2240926302.jpg - as minky/
#             「初恋」赵露思同款耳钉花朵耳环耳夹仙气森系超仙女无耳洞蚊香盘
#         /b9a78b88d9.jpg
# SUCCESS - saved https://gd4.alicdn.com/imgextra/i4/2240926302/O1CN01dQlTWe1wQMZxoDDhk_!!2240926302.jpg - as minky/
#             「初恋」赵露思同款耳钉花朵耳环耳夹仙气森系超仙女无耳洞蚊香盘
#         /4cd5560949.jpg
# https://item.taobao.com/item.htm?spm=a312a.7700824.w4004-22612662286.4.5f519e831e9NGj&id=611988650152
# no login dialogue2 IMPORTANTTT _____________
# 0
# 1
# 2
# 3
# 4
# gg2
# 5
# fail
# gg2
# 6
# fail
# gg2
# 7
# fail
# gg2
# 8
# fail
# gg2
# 9
# fail
# gg2
# 10
# fail
# gg2
# 11
# fail
# gg2
# 12
# fail
# gg2
# 13
# fail
# gg2
# 14
# fail
# https://world.taobao.com/item/611988650152.htm
# https://cloud.video.taobao.com/play/u/2240926302/p/2/e/6/t/1/258815679565.mp4?appKey=38829
# SUCCESS - saved https://gd1.alicdn.com/imgextra/i4/2240926302/O1CN01XHBYYJ1wQMbDvjF7S_!!2240926302.jpg - as minky/
#             「扑蝶」贝母蝴蝶耳夹无耳洞女小众设计感耳饰耳钉仙气森系超仙
#         /8c16121619.jpg
# SUCCESS - saved https://gd2.alicdn.com/imgextra/i2/2240926302/O1CN01tzRjYB1wQMbyuurkn_!!2240926302.jpg - as minky/
#             「扑蝶」贝母蝴蝶耳夹无耳洞女小众设计感耳饰耳钉仙气森系超仙
#         /22c1610dd8.jpg
# SUCCESS - saved https://gd1.alicdn.com/imgextra/i1/2240926302/O1CN01TtryWX1wQMbtIixjh_!!2240926302.jpg - as minky/
#             「扑蝶」贝母蝴蝶耳夹无耳洞女小众设计感耳饰耳钉仙气森系超仙
#         /2888d552cc.jpg
# SUCCESS - saved https://gd1.alicdn.com/imgextra/i1/2240926302/O1CN014b4H7m1wQMbBELKib_!!2240926302.jpg - as minky/
#             「扑蝶」贝母蝴蝶耳夹无耳洞女小众设计感耳饰耳钉仙气森系超仙
#         /a4fb93a310.jpg
# SUCCESS - saved https://gd3.alicdn.com/imgextra/i3/2240926302/O1CN01WyPTdd1wQMacyBjaa_!!2240926302.jpg - as minky/
#             「扑蝶」贝母蝴蝶耳夹无耳洞女小众设计感耳饰耳钉仙气森系超仙
#         /9f940294d9.jpg
# https://item.taobao.com/item.htm?spm=a312a.7700824.w4004-22612662286.6.5f519e831e9NGj&id=624361503104
# no login dialogue1 IMPORTANTTT _____________
# 0
# 1
# 2
# 3
# 4
# gg2
# 5
# fail
# gg2
# 6
# fail
# gg2
# 7
# fail
# gg2
# 8
# fail
# gg2
# 9
# fail
# gg2
# 10
# fail
# gg2
# 11
# fail
# gg2
# 12
# fail
# gg2
# 13
# fail
# gg2
# 14
# fail
# https://world.taobao.com/item/624361503104.htm
# https://cloud.video.taobao.com/play/u/2240926302/p/2/e/6/t/1/273742865285.mp4?appKey=38829
# SUCCESS - saved https://gd1.alicdn.com/imgextra/i1/2240926302/O1CN01ZzHWd61wQMcUmJBqo_!!2240926302-0-lubanu-s.jpg - as minky/
#             「艾尔莎殿下」巴洛克真珍珠项链锁骨链女短款月光石颈链chocker
#         /e1d975344c.jpg
# SUCCESS - saved https://gd4.alicdn.com/imgextra/i4/2240926302/O1CN01Pz8WJS1wQMcSiSEyF_!!2240926302-0-lubanu-s.jpg - as minky/
#             「艾尔莎殿下」巴洛克真珍珠项链锁骨链女短款月光石颈链chocker
#         /312ceb539c.jpg
# SUCCESS - saved https://gd2.alicdn.com/imgextra/i2/2240926302/O1CN01kFiDrQ1wQMcd5wMkL_!!2240926302-0-lubanu-s.jpg - as minky/
#             「艾尔莎殿下」巴洛克真珍珠项链锁骨链女短款月光石颈链chocker
#         /f354bbf05c.jpg
# SUCCESS - saved https://gd4.alicdn.com/imgextra/i4/2240926302/O1CN01PaGBY51wQMcdPC9T7_!!2240926302-0-lubanu-s.jpg - as minky/
#             「艾尔莎殿下」巴洛克真珍珠项链锁骨链女短款月光石颈链chocker
#         /f9a7641ace.jpg
# SUCCESS - saved https://gd4.alicdn.com/imgextra/i4/2240926302/O1CN01i6HemM1wQMcUI4ORw_!!2240926302-0-lubanu-s.jpg - as minky/
#             「艾尔莎殿下」巴洛克真珍珠项链锁骨链女短款月光石颈链chocker
#         /5114ddb0f0.jpg
# https://item.taobao.com/item.htm?spm=a312a.7700824.w4004-22612662286.8.5f519e831e9NGj&id=617341972356
# no login dialogue2 IMPORTANTTT _____________
# 0
# 1
# 2
# 3
# 4
# gg2
# 5
# fail
# gg2
# 6
# fail
# gg2
# 7
# fail
# gg2
# 8
# fail
# gg2
# 9
# fail
# gg2
# 10
# fail
# gg2
# 11
# fail
# gg2
# 12
# fail
# gg2
# 13
# fail
# gg2
# 14
# fail
# https://world.taobao.com/item/617341972356.htm
# https://cloud.video.taobao.com/play/u/2240926302/p/2/e/6/t/1/262867647462.mp4?appKey=38829
# SUCCESS - saved https://gd4.alicdn.com/imgextra/i1/2240926302/O1CN0107meSw1wQMbdlQvkI_!!2240926302.jpg - as minky/
#             「南宫一梦」蝴蝶耳饰耳夹无耳洞女耳钉耳环仙气森系超仙设计感
#         /56cd79f507.jpg
# SUCCESS - saved https://gd2.alicdn.com/imgextra/i2/2240926302/O1CN01U3hChe1wQMcVlrlfo_!!2240926302-0-lubanu-s.jpg - as minky/
#             「南宫一梦」蝴蝶耳饰耳夹无耳洞女耳钉耳环仙气森系超仙设计感
#         /25158f517d.jpg
# SUCCESS - saved https://gd2.alicdn.com/imgextra/i2/2240926302/O1CN01JCP6EI1wQMcRTgtt4_!!2240926302-0-lubanu-s.jpg - as minky/
#             「南宫一梦」蝴蝶耳饰耳夹无耳洞女耳钉耳环仙气森系超仙设计感
#         /a7bd2cd649.jpg
# SUCCESS - saved https://gd4.alicdn.com/imgextra/i4/2240926302/O1CN01TkcQNV1wQMcUMP7Ip_!!2240926302-0-lubanu-s.jpg - as minky/
#             「南宫一梦」蝴蝶耳饰耳夹无耳洞女耳钉耳环仙气森系超仙设计感
#         /c33fa8a6b5.jpg
# SUCCESS - saved https://gd3.alicdn.com/imgextra/i3/2240926302/O1CN01rPqERm1wQMbriinmW_!!2240926302.jpg - as minky/
#             「南宫一梦」蝴蝶耳饰耳夹无耳洞女耳钉耳环仙气森系超仙设计感
#         /38cec07223.jpg
